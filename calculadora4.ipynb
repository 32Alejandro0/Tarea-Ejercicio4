# %%
while (True):
 print("1 Suma")
 print("2 Resta")
 print("3 Multiplicacion")
 print("4 Division")
 opcion=float (input("Eliga una opcion\n"))
 if (opcion==1):
   print("Se realizara una suma")
   a=float (input("Eliga un numero\n"))
   b=float (input("Eliga un numero\n"))
   resultado=a+b
   print ("El resultado de la suma es:",resultado)
 elif (opcion==2):
   print("Se realizara una resta")
   a=float (input("Eliga un numero\n"))
   b=float (input("Eliga un numero\n"))
   resultado=a-b
   print ("El resultado de la resta es:",resultado)   
 elif (opcion==3):
   print("Se realizara una multiplicacion")
   a=float (input("Eliga un numero\n"))
   b=float (input("Eliga un numero\n"))
   resultado=a*b
   print ("El resultado de la multiplicacion es:",resultado)
 elif (opcion==4):
   print("Se realizara una division")
   a=float (input("Eliga un numero\n")) 
   b=float (input("Eliga un numero\n"))
   while (b==0):
    b= float (input("No es posible dividir entre 0 digite otro numero:"))
   resultado=a/b
   print("El resultado de la division es:", resultado)
 else:
    print("Numero invalido:")
# Out:
# 1 Suma
# 2 Resta
# 3 Multiplicacion
# 4 Division
# Eliga una opcion
# 4
# Se realizara una division
# Eliga un numero
# 10
# Eliga un numero
# 0
# No es posible dividir entre 0 digite otro numero:0
# No es posible dividir entre 0 digite otro numero:0
# No es posible dividir entre 0 digite otro numero:5
# El resultado de la division es: 2.0
# 1 Suma
# 2 Resta
# 3 Multiplicacion
# 4 Division
